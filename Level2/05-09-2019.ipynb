# %% [markdown]
# # Markdown Introduction

# %% [markdown]
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ##### heading5
# ###### heading6

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*

# %% [markdown]
# <strike>strike</strike><h1>hi</h1>

# %% [markdown]
# 'highlight text'

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%HTML
# <iframe width="853" height="480" src="https://www.youtube.com/embed/rKaN8JC70Iw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="853" height="480" src="https://www.youtube.com/embed/rKaN8JC70Iw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * R programming
# * scripting language
#  - html
#  - css

# %% [markdown]
# # Python Programming

# %%
print("Hi! Yamini")
print("MSTP")
print(1)
# Out:
# Hi! Yamini
# MSTP
# 1

# %% [markdown]
# ## Operators

# %% [markdown]
# * Arithmetic operators
# * Logical operators
# * Relational operators
# * Assignment operators
# * Bitwise operators
# * Identity operators
# * Membership operators

# %% [markdown]
# ### Airthmetic operators

# %%
print(10+20)
print(20-10)
print(20*30)
print(10/6)
# Out:
# 30
# 10
# 600
# 1.6666666666666667

# %%
type(1)
# Out:
# int

# %%
type(10/3)
# Out:
# float

# %%
type(10//3)
# Out:
# int

# %%
10%3
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %% [markdown]
# ### Logical operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ### Relational operators

# %%
2==3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2<10
# Out:
# True

# %%
10>20
# Out:
# False

# %% [markdown]
# ### Assignment operators

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
a="HI"

# %%
type(a)
# Out:
# str

# %%
a=b=c=10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
a,b,c=10,20,30

# %%
a,b,c
# Out:
# (10, 20, 30)

# %%
a
b
c
# Out:
# 30

# %%
print(a)
print (b)
c
# Out:
# 10
# 20
# 30

# %%
a,b=b,a

# %%
a,b
# Out:
# (20, 10)

# %%
a=1
a
# Out:
# 1

# %%
a++ #it is not supported in python
# Out:
#   File "<ipython-input-40-16a96addd613>", line 1
#     a++ #it is not supported in python
#                                       ^
# SyntaxError: invalid syntax

# %%
a=a+1
a
# Out:
# 2

# %%
a+=1
a
# Out:
# 3

# %%
a-=1
a
# Out:
# 2

# %%
a=3
a*=2
a
# Out:
# 6

# %%
a//=3
a
# Out:
# 2

# %% [markdown]
# ### Bitwise operators

# %%
4 & 7
# Out:
# 4

# %% [markdown]
# 4-1 0 0
# 7-1 1 1
# &-1 0 0

# %%
7|4
# Out:
# 7

# %%
8<<2
# Out:
# 32

# %%
8>>2
# Out:
# 2

# %% [markdown]
# ### Identity operators

# %%
2==3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2 !=3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ### Membership operators

# %%
"ya" in "yamini"
# Out:
# True

# %%
"ya" in "Yamini"
# Out:
# False

# %%
"g" not in "yamini"
# Out:
# True
